# %% [markdown]
# <a href="https://colab.research.google.com/github/valeskaleiva/cancion/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
url='https://raw.githubusercontent.com/valeskaleiva/datascience/main/adidas.csv'
df= pd.read_csv(url,sep=',', header=None)
df.head()
# Out:
#     0            1            2                    3          4         5   \
# 0  NaN     Retailer  Retailer ID         Invoice Date     Region     State
# 1  0.0  Foot Locker      1185732  2020-01-01 00:00:00  Northeast  New York
# 2  1.0  Foot Locker      1185732  2020-01-02 00:00:00  Northeast  New York
# 3  2.0  Foot Locker      1185732  2020-01-03 00:00:00  Northeast  New York
# 4  3.0  Foot Locker      1185732  2020-01-04 00:00:00  Northeast  New York
#
#          6                          7               8           9   \
# 0      City                    Product  Price per Unit  Units Sold
# 1  New York      Men's Street Footwear              50        1200
# 2  New York    Men's Athletic Footwear              50        1000
# 3  New York    Women's Street Footwear              40        1000
# 4  New York  Women's Athletic Footwear              45         850
#
#             10                11                12            13
# ...
